# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv('perfiles_simulados_2000.csv')

# %%
df.shape
# Out:
# (2000, 24)

# %%
df.head()
# Out:
#    age                                         avatar_url  \
# 0   20  https://api.dicebear.com/7.x/avataaars/svg?see...
# 1   28  https://api.dicebear.com/7.x/avataaars/svg?see...
# 2   24  https://api.dicebear.com/7.x/avataaars/svg?see...
# 3   28  https://api.dicebear.com/7.x/avataaars/svg?see...
# 4   20  https://api.dicebear.com/7.x/avataaars/svg?see...
#
#                                                  bio          city  \
# 0  ¡Hola! Soy estudiante y busco un lugar genial ...   Bucaramanga
# 1  ¡Hola! Soy estudiante y busco un lugar genial ...  Barranquilla
# 2  ¡Hola! Soy estudiante y busco un lugar genial ...        Bogotá
# 3  ¡Hola! Soy estudiante y busco un lugar genial ...     Manizales
# 4  ¡Hola! Soy estudiante y busco un lugar genial ...      Medellín
#
#    cleanliness_level      clerk_user_id           created_at  \
# 0                  1  user_feda7edba1a1  2023-11-19T23:56:00
# 1                  5  user_7d12a91e107a  2023-07-05T12:21:00
# ...

# %%
print(df.columns)
# Out:
# Index(['age', 'avatar_url', 'bio', 'city', 'cleanliness_level',
#        'clerk_user_id', 'created_at', 'email', 'first_name', 'has_co_debtor',
#        'id', 'interests', 'job_title', 'last_name', 'lifestyle_tags',
#        'monthly_budget', 'phone', 'profile_completed', 'profile_images',
#        'semester', 'social_level', 'university_name', 'updated_at',
#        'user_mode'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                2000 non-null   int64
#  1   avatar_url         2000 non-null   str
#  2   bio                2000 non-null   str
#  3   city               2000 non-null   str
#  4   cleanliness_level  2000 non-null   int64
#  5   clerk_user_id      2000 non-null   str
#  6   created_at         2000 non-null   str
#  7   email              2000 non-null   str
#  8   first_name         2000 non-null   str
#  9   has_co_debtor      2000 non-null   bool
#  10  id                 2000 non-null   str
#  11  interests          2000 non-null   str
#  12  job_title          2000 non-null   str
#  13  last_name          2000 non-null   str
#  14  lifestyle_tags     2000 non-null   str
#  15  monthly_budget     2000 non-null   int64
#  16  phone              2000 non-null   str
# ...

# %%
df['university_name'].hist()
# Out:
# <Axes: >
